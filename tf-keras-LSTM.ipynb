# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Model, layers, optimizers, datasets

# %%
x = tf.random.normal(shape=(32, 20, 100), mean=0., stddev=1.)

# %%
lstm = layers.LSTM(units=10)

# %%
x.shape
# Out:
# TensorShape([32, 20, 100])

# %%
out = lstm(x)
out.shape
# Out:
# TensorShape([32, 10])

# %%
lstm2 = layers.LSTM(units=10, return_sequences=True, return_state=True) # [batch_size, timesteps, features]
# return_sequences : output sequences의 마지막 output을 return할지(default=False), full sequence를 return할지(True)
# return_state : output이외에 last state(hidden_state, cell_state)도 return할지 말지

# %%
output2, final_hidden_state, final_cell_state = lstm2(x)

# %%
output2.shape
# Out:
# TensorShape([32, 20, 10])

# %%
final_hidden_state.shape
# Out:
# TensorShape([32, 10])

# %%
final_cell_state.shape
# Out:
# TensorShape([32, 10])

# %%
class LSTM(Model):
    def __init__(self, units1, units2, num_classes):
        super(LSTM, self).__init__()
        self.sequential = tf.keras.Sequential([
            layers.LSTM(units1, return_sequences=True),
            layers.BatchNormalization(),
            layers.LSTM(units2),
            layers.BatchNormalization(),
            layers.Dense(num_classes, activation=tf.nn.softmax)
        ])

    def call(self, x):
        out = self.sequential(x)
        return out

# %%
(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train / 255.
x_test = x_test / 255.

# %%
units_1 = 128
units_2 = 256
num_classes = 10

model = LSTM(units_1, units_2, num_classes)

# %%
model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
batch_size = 128
epochs = 3

model.fit(x_train, y_train,
          validation_data=(x_test, y_test),
          batch_size=batch_size,
          epochs=epochs)
# Out:
# Epoch 1/3
# 469/469 [==============================] - 200s 414ms/step - loss: 0.6396 - accuracy: 0.7990 - val_loss: 1.2393 - val_accuracy: 0.5377
# Epoch 2/3
# 469/469 [==============================] - 198s 423ms/step - loss: 0.3151 - accuracy: 0.9025 - val_loss: 0.2839 - val_accuracy: 0.9070
# Epoch 3/3
# 469/469 [==============================] - 185s 394ms/step - loss: 0.2260 - accuracy: 0.9296 - val_loss: 0.2446 - val_accuracy: 0.9220

# %%
class Bi_LSTM(Model):
    def __init__(self, units1, units2, num_classes):
        super(Bi_LSTM, self).__init__()
        
        self.sequential = tf.keras.Sequential([
            layers.Bidirectional(layers.LSTM(units1, return_sequences=True)),
            layers.BatchNormalization(),
            layers.Bidirectional(layers.LSTM(units2)),
            layers.BatchNormalization(),
            layers.Dense(num_classes, activation=tf.nn.softmax)
        ])

    def call(self, x):
        out = self.sequential(x)
        return out

# %%
model2 = Bi_LSTM(units_1, units_2, num_classes)

# %%
model2.compile(optimizer='sgd',
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

# %%
model2.fit(x_train, y_train,
           validation_data=(x_test, y_test),
           batch_size=batch_size,
           epochs=epochs)
# Out:
# Epoch 1/3
# 469/469 [==============================] - 407s 849ms/step - loss: 0.4542 - accuracy: 0.8685 - val_loss: 0.6365 - val_accuracy: 0.8166
# Epoch 2/3
# 469/469 [==============================] - 408s 869ms/step - loss: 0.2045 - accuracy: 0.9411 - val_loss: 0.1674 - val_accuracy: 0.9492
# Epoch 3/3
# 469/469 [==============================] - 394s 840ms/step - loss: 0.1485 - accuracy: 0.9566 - val_loss: 0.1532 - val_accuracy: 0.9483
