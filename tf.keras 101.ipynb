# %% [markdown]
# ### tf.keras Practice!
#
# - CIFAR10 이미지 데이터셋을 분류하는 문제를 풀어봅니다!

# %%
# !nvidia-smi
# Out:
# Wed Nov 30 04:51:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
import numpy as np
tf.__version__
# Out:
# '2.9.2'

# %%
# DNN
from tensorflow import keras
import tensorflow as tf
# datasets
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras import Sequential

# %%
# load CIFAR10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
## RGB (3-channel)
# 32 x 32 - R -> pixel matrix
# 32 x 32 - G
# 32 x 32 - B
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %% [markdown]
# ### Model Training
#
# 1. model architecture
#
# - Hidden Layer (뒤로 갈수록 hidden node수가 작아짐)
#
# - Activation function : 'sigmoid' / 'relu'
#
#
#
# 2. loss optimization
#
#
# - optimizer : 'sgd', 'momentum', 'adam'
#
# - batch_size : 1 -> 8-> 32 -> 64 -> 128 -> 256 -> 512 -> 2048 -> ...
#
# - epochs : 10 -> 30 -> 100 -> 10000 (overfitting)

# %%
model = Sequential([
    Input(shape=(32, 32, 3)),
    Flatten(),  # 32x32x3 ---> 3072  (input layer의 node 수)
    Dense(units=1024, activation='relu'),
    Dense(units=256, activation='relu'),
    Dense(units=128, activation='relu'),
    Dense(units=10, activation='softmax') # output layer
])

model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_14 (Flatten)        (None, 3072)              0
#
#  dense_79 (Dense)            (None, 1024)              3146752
#
#  dense_80 (Dense)            (None, 256)               262400
#
#  dense_81 (Dense)            (None, 128)               32896
#
#  dense_82 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 3,443,338
# Trainable params: 3,443,338
# Non-trainable params: 0
# _________________________________________________________________

# %%
# y_train # 0 ~ 9

# %%
# compile
from tensorflow.keras.optimizers import SGD, Adam

lr = 1e-5
loss_fn = 'sparse_categorical_crossentropy' # target vector가 정수인 경우.
# optimizer = SGD(learning_rate=lr)
# optimizer = SGD(learning_rate=lr, momentum=0.5)
optimizer = Adam(learning_rate=lr)
epochs = 50 # 모든 데이터가 학습에 
batch_size = 128

model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %%
# fit
model.fit(x=X_train,
          y=y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 391/391 [==============================] - 2s 5ms/step - loss: 20.8399 - accuracy: 0.2006 - val_loss: 11.7700 - val_accuracy: 0.2331
# Epoch 2/50
# 391/391 [==============================] - 2s 5ms/step - loss: 9.9564 - accuracy: 0.2497 - val_loss: 8.9054 - val_accuracy: 0.2554
# Epoch 3/50
# 391/391 [==============================] - 2s 4ms/step - loss: 7.7095 - accuracy: 0.2769 - val_loss: 7.1937 - val_accuracy: 0.2774
# Epoch 4/50
# 391/391 [==============================] - 2s 4ms/step - loss: 6.5021 - accuracy: 0.2934 - val_loss: 6.3413 - val_accuracy: 0.2934
# Epoch 5/50
# 391/391 [==============================] - 2s 4ms/step - loss: 5.6568 - accuracy: 0.3067 - val_loss: 5.8024 - val_accuracy: 0.2915
# Epoch 6/50
# 391/391 [==============================] - 2s 4ms/step - loss: 5.1395 - accuracy: 0.3166 - val_loss: 5.4972 - val_accuracy: 0.3108
# Epoch 7/50
# 391/391 [==============================] - 2s 4ms/step - loss: 4.6647 - accuracy: 0.3274 - val_loss: 4.8942 - val_accuracy: 0.3165
# Epoch 8/50
# 391/391 [==============================] - 2s 4ms/step - loss: 4.3321 - accuracy: 0.3381 - val_loss: 4.6378 - val_accuracy: 0.3183
# Epoch 9/50
# 391/391 [==============================] - 2s 4ms/step - loss: 4.0172 - accuracy: 0.3475 - val_loss: 4.4528 - val_accuracy: 0.3200
# Epoch 10/50
# 391/391 [==============================] - 2s 4ms/step - loss: 3.7638 - accuracy: 0.3590 - val_loss: 4.1284 - val_accuracy: 0.3357
# Epoch 11/50
# 391/391 [==============================] - 2s 4ms/step - loss: 3.5509 - accuracy: 0.3682 - val_loss: 3.9581 - val_accuracy: 0.3387
# Epoch 12/50
# 391/391 [==============================] - 2s 4ms/step - loss: 3.3835 - accuracy: 0.3738 - val_loss: 3.9074 - val_accuracy: 0.3395
# Epoch 13/50
# 391/391 [==============================] - 2s 4ms/step - loss: 3.2065 - accuracy: 0.3837 - val_loss: 3.7123 - val_accuracy: 0.3376
# Epoch 14/50
# 391/391 [==============================] - 2s 4ms/step - loss: 3.0771 - accuracy: 0.3913 - val_loss: 3.6916 - val_accuracy: 0.3402
# Epoch 15/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.9099 - accuracy: 0.4013 - val_loss: 3.6688 - val_accuracy: 0.3458
# Epoch 16/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.8120 - accuracy: 0.4092 - val_loss: 3.4582 - val_accuracy: 0.3532
# Epoch 17/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.6881 - accuracy: 0.4174 - val_loss: 3.5362 - val_accuracy: 0.3404
# Epoch 18/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.6104 - accuracy: 0.4253 - val_loss: 3.5043 - val_accuracy: 0.3531
# Epoch 19/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.5061 - accuracy: 0.4328 - val_loss: 3.2224 - val_accuracy: 0.3690
# Epoch 20/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.4292 - accuracy: 0.4407 - val_loss: 3.2162 - val_accuracy: 0.3619
# Epoch 21/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.3281 - accuracy: 0.4507 - val_loss: 3.1740 - val_accuracy: 0.3683
# Epoch 22/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.2731 - accuracy: 0.4552 - val_loss: 3.0387 - val_accuracy: 0.3725
# Epoch 23/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.2105 - accuracy: 0.4619 - val_loss: 3.0709 - val_accuracy: 0.3729
# Epoch 24/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.1271 - accuracy: 0.4712 - val_loss: 3.0397 - val_accuracy: 0.3775
# Epoch 25/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.0704 - accuracy: 0.4799 - val_loss: 2.9678 - val_accuracy: 0.3802
# Epoch 26/50
# 391/391 [==============================] - 2s 4ms/step - loss: 2.0164 - accuracy: 0.4844 - val_loss: 3.1089 - val_accuracy: 0.3769
# Epoch 27/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.9792 - accuracy: 0.4932 - val_loss: 2.9221 - val_accuracy: 0.3797
# Epoch 28/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.9304 - accuracy: 0.4974 - val_loss: 2.8606 - val_accuracy: 0.3890
# Epoch 29/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.8313 - accuracy: 0.5085 - val_loss: 2.9362 - val_accuracy: 0.3863
# Epoch 30/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.8254 - accuracy: 0.5132 - val_loss: 3.0019 - val_accuracy: 0.3747
# Epoch 31/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.7600 - accuracy: 0.5228 - val_loss: 2.8641 - val_accuracy: 0.3938
# Epoch 32/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.7091 - accuracy: 0.5296 - val_loss: 2.9885 - val_accuracy: 0.3726
# Epoch 33/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.6842 - accuracy: 0.5343 - val_loss: 2.8786 - val_accuracy: 0.3875
# Epoch 34/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.6399 - accuracy: 0.5413 - val_loss: 2.7675 - val_accuracy: 0.3997
# Epoch 35/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.6139 - accuracy: 0.5447 - val_loss: 2.7568 - val_accuracy: 0.3935
# Epoch 36/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.5579 - accuracy: 0.5557 - val_loss: 2.8621 - val_accuracy: 0.3913
# Epoch 37/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.5165 - accuracy: 0.5625 - val_loss: 2.7508 - val_accuracy: 0.3993
# Epoch 38/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.5104 - accuracy: 0.5670 - val_loss: 2.6955 - val_accuracy: 0.4082
# Epoch 39/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.4589 - accuracy: 0.5747 - val_loss: 2.7539 - val_accuracy: 0.4026
# Epoch 40/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.4467 - accuracy: 0.5755 - val_loss: 2.7083 - val_accuracy: 0.4096
# Epoch 41/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.4090 - accuracy: 0.5825 - val_loss: 2.6590 - val_accuracy: 0.4035
# Epoch 42/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.3776 - accuracy: 0.5892 - val_loss: 2.6423 - val_accuracy: 0.4133
# Epoch 43/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.3590 - accuracy: 0.5950 - val_loss: 2.6957 - val_accuracy: 0.4082
# Epoch 44/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.3418 - accuracy: 0.5984 - val_loss: 2.7370 - val_accuracy: 0.4014
# Epoch 45/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.3042 - accuracy: 0.6081 - val_loss: 2.5914 - val_accuracy: 0.4180
# Epoch 46/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.2668 - accuracy: 0.6133 - val_loss: 2.7426 - val_accuracy: 0.4043
# Epoch 47/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.2733 - accuracy: 0.6129 - val_loss: 2.6660 - val_accuracy: 0.4077
# Epoch 48/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.2261 - accuracy: 0.6232 - val_loss: 2.6987 - val_accuracy: 0.4096
# Epoch 49/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.2179 - accuracy: 0.6255 - val_loss: 2.5507 - val_accuracy: 0.4188
# Epoch 50/50
# 391/391 [==============================] - 2s 4ms/step - loss: 1.1985 - accuracy: 0.6302 - val_loss: 2.6671 - val_accuracy: 0.4070

# %%
# evaluate
loss, acc = model.evaluate()
print("Loss : %.4f, Test Accuracy : %.4f" % (loss, acc))

# %%
## 어떤 Hyper-parameter setting에서 최고의 성능이 나왔나요?
