# %% [markdown]
# <a href="https://colab.research.google.com/github/jjooki/TIL/blob/main/bike_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/dacon/bike
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/dacon/bike

# %%
import random
import pandas as pd
import numpy as np
import os
import re
from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from tqdm.auto import tqdm

import warnings
warnings.filterwarnings(action='ignore') 

base_path = Path('__file__').resolve().parent
train = pd.read_csv(base_path / 'data/train.csv')
submission = pd.read_csv(base_path / 'data/sample_submission.csv')

regions = ['광진구', '동대문구', '성동구', '중랑구']
metric = 'mae'

train
# Out:
#             일시    광진구   동대문구    성동구    중랑구
# 0     20180101  0.592  0.368  0.580  0.162
# 1     20180102  0.840  0.614  1.034  0.260
# 2     20180103  0.828  0.576  0.952  0.288
# 3     20180104  0.792  0.542  0.914  0.292
# 4     20180105  0.818  0.602  0.994  0.308
# ...        ...    ...    ...    ...    ...
# 1456  20211227  3.830  3.416  2.908  2.350
# 1457  20211228  4.510  3.890  3.714  2.700
# 1458  20211229  4.490  3.524  3.660  2.524
# 1459  20211230  4.444  3.574  3.530  2.506
# 1460  20211231  3.616  3.210  2.620  2.146
#
# [1461 rows x 5 columns]

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
CFG = {
    'X_RANGE':334, # 예측하려는 시점을 X_RANGE 만큼의 이전 일자의 데이터로부터 예측 및 학습
    'EPOCHS':200,
    'LEARNING_RATE':1e-2,
    'BATCH_SIZE':128,
    'SEED':42
}

# %%
import copy

def make_ymd_feature(data):
    df = data.copy(deep=True)
    df['일시'] = df['일시'].astype(str)
    df['년'] = df['일시'].str[:4].astype(int)/1000.
    df['월'] = df['일시'].str[4:6].astype(int)/12.
    df['일'] = df['일시'].str[6:8].astype(int)/31.
    df = df[['년', '월', '일', '광진구', '동대문구', '성동구', '중랑구']]
    return df

# %%
def get_x_y_data(df, infer=False):
    # x_range : x일전까지의 데이터를 통해 예측
    x_data = []
    y_data = []
    for i in tqdm(range(CFG['X_RANGE'], len(df))):
        x_data.append(np.array(df.loc[i-CFG['X_RANGE']:i-1, ['년', '월', '일', '광진구', '동대문구', '성동구', '중랑구']]).astype(float))
        y_data.append(np.array(df.loc[i, ['광진구', '동대문구', '성동구', '중랑구']]).astype(float))
    if infer:
        return x_data
    else:
        return x_data, y_data

# %%
val = train.iloc[1096-CFG['X_RANGE']:].reset_index().drop(columns='index') # 20210101 ~ 20211231
# 위의 1096-CFG['X_RANGE']의 이유는 20210101을 예측하기 위해서는 이전 X_RANGE만큼의 일수가 필요하므로
train = train.iloc[:1096].reset_index().drop(columns='index') # 20180101 ~ 20201231

# %%
train
# Out:
#             일시    광진구   동대문구    성동구    중랑구
# 0     20180101  0.592  0.368  0.580  0.162
# 1     20180102  0.840  0.614  1.034  0.260
# 2     20180103  0.828  0.576  0.952  0.288
# 3     20180104  0.792  0.542  0.914  0.292
# 4     20180105  0.818  0.602  0.994  0.308
# ...        ...    ...    ...    ...    ...
# 1091  20201227  3.528  2.604  3.258  2.038
# 1092  20201228  4.542  3.588  4.506  2.480
# 1093  20201229  3.694  3.054  3.222  2.118
# 1094  20201230  2.366  1.812  2.012  1.174
# 1095  20201231  2.366  2.018  1.988  1.358
#
# [1096 rows x 5 columns]

# %%
train = make_ymd_feature(train)
val = make_ymd_feature(val)

# %%
train_x, train_y = get_x_y_data(train)
# Out:
#   0%|          | 0/1091 [00:00<?, ?it/s]

# %%
val_x, val_y = get_x_y_data(val)
# Out:
#   0%|          | 0/365 [00:00<?, ?it/s]

# %%
class toTensor(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    
    def __getitem__(self, index):
        if self.y is not None:
            return torch.Tensor(self.X[index]), torch.Tensor(self.y[index])
        else:
            return torch.Tensor(self.X[index])

    def __len__(self):
        return len(self.X)

# %%
train_tensor = toTensor(train_x, train_y)
train_loader = DataLoader(train_tensor,
                          batch_size=CFG['BATCH_SIZE'],
                          shuffle=True, num_workers=0)

val_tensor = toTensor(val_x, val_y)
val_loader = DataLoader(val_tensor,
                        batch_size=CFG['BATCH_SIZE'],
                        shuffle=False, num_workers=0)

# %%
class BaseModel(nn.Module):
    def __init__(self):
        super(BaseModel, self).__init__()
        self.lstm = nn.LSTM(input_size=7,
                            hidden_size=256,
                            num_layers=4,
                            batch_first=True)
        
        self.multioutput_reg = nn.Sequential(
            nn.Linear(in_features=256, out_features=128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Linear(in_features=128, out_features=4)
        )

    def forward(self, x):
        hidden, _ = self.lstm(x)
        output = self.multioutput_reg(hidden[:,-1,:])
        return output

# %%
def train(model, optimizer, train_loader, val_loader, scheduler, device):
    model.to(device)
    criterion = nn.L1Loss().to(device)
    
    best_loss = 9999999
    best_model = None
    
    for epoch in range(1, CFG['EPOCHS']+1):
        model.train()
        train_loss = []
        for X, Y in iter(train_loader):
            X = X.to(device)
            Y = Y.to(device)
            
            optimizer.zero_grad()
            
            output = model(X)
            loss = criterion(output, Y)
            
            loss.backward()
            optimizer.step()
            
            train_loss.append(loss.item())
        
        _train_loss = np.mean(train_loss)
        
        val_mae = validation(model, val_loader, criterion, device)
        print(f'Epoch : [{epoch}] Train Loss : [{_train_loss:.5f}] Val MAE : [{val_mae:.5f}]')
        
        if scheduler is not None:
            scheduler.step(val_mae)
            
        if best_loss > val_mae:
            best_loss = val_mae
            best_model = model 
    return best_model

# %%
def validation(model, val_loader, criterion, device):
    model.eval()
    val_loss = []
    with torch.no_grad():
        for X, Y in iter(val_loader):
            X = X.to(device)
            Y = Y.to(device)
            
            output = model(X)
            
            loss = criterion(output, Y)
            
            val_loss.append(loss.item())
    
    _val_loss = np.mean(val_loss)
    return _val_loss

# %%
model = BaseModel()

optimizer = torch.optim.Adam(params = model.parameters(), lr = CFG["LEARNING_RATE"])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=4,threshold_mode='abs',min_lr=1e-8, verbose=True)
best_model = train(model, optimizer, train_loader, val_loader, scheduler, device) # 2018.01.01 ~ 2020.12.31 까지 데이터로 학습
# Out:
# Epoch : [1] Train Loss : [2.93666] Val MAE : [4.33689]
# Epoch : [2] Train Loss : [1.40875] Val MAE : [3.77486]
# Epoch : [3] Train Loss : [1.30871] Val MAE : [3.54277]
# Epoch : [4] Train Loss : [1.22130] Val MAE : [2.40812]
# Epoch : [5] Train Loss : [1.03123] Val MAE : [2.56708]
# Epoch : [6] Train Loss : [1.06956] Val MAE : [2.16181]
# Epoch 00006: reducing learning rate of group 0 to 5.0000e-03.
# Epoch : [7] Train Loss : [0.99835] Val MAE : [2.31106]
# Epoch : [8] Train Loss : [0.97845] Val MAE : [2.76836]
# Epoch : [9] Train Loss : [1.00749] Val MAE : [1.56494]
# Epoch : [10] Train Loss : [0.95972] Val MAE : [1.54772]
# Epoch : [11] Train Loss : [0.94794] Val MAE : [1.59305]
# Epoch 00011: reducing learning rate of group 0 to 2.5000e-03.
# Epoch : [12] Train Loss : [0.93937] Val MAE : [1.69249]
# Epoch : [13] Train Loss : [0.92452] Val MAE : [1.85762]
# Epoch : [14] Train Loss : [0.90702] Val MAE : [1.56977]
# Epoch : [15] Train Loss : [0.89983] Val MAE : [1.61063]
# Epoch : [16] Train Loss : [0.88097] Val MAE : [1.52560]
# Epoch 00016: reducing learning rate of group 0 to 1.2500e-03.
# Epoch : [17] Train Loss : [0.91217] Val MAE : [1.59264]
# Epoch : [18] Train Loss : [0.89510] Val MAE : [1.78783]
# Epoch : [19] Train Loss : [0.88125] Val MAE : [1.47250]
# Epoch : [20] Train Loss : [0.84810] Val MAE : [1.44823]
# Epoch : [21] Train Loss : [0.86721] Val MAE : [1.65972]
# Epoch 00021: reducing learning rate of group 0 to 6.2500e-04.
# Epoch : [22] Train Loss : [0.87575] Val MAE : [1.61347]
# Epoch : [23] Train Loss : [0.89992] Val MAE : [1.48588]
# Epoch : [24] Train Loss : [0.90033] Val MAE : [1.59695]
# Epoch : [25] Train Loss : [0.83735] Val MAE : [1.47952]
# Epoch : [26] Train Loss : [0.86305] Val MAE : [1.47724]
# Epoch 00026: reducing learning rate of group 0 to 3.1250e-04.
# Epoch : [27] Train Loss : [0.85952] Val MAE : [1.53550]
# Epoch : [28] Train Loss : [0.83573] Val MAE : [1.56122]
# Epoch : [29] Train Loss : [0.87141] Val MAE : [1.47504]
# Epoch : [30] Train Loss : [0.88956] Val MAE : [1.47739]
# Epoch : [31] Train Loss : [0.87346] Val MAE : [1.50201]
# Epoch 00031: reducing learning rate of group 0 to 1.5625e-04.
# Epoch : [32] Train Loss : [0.84738] Val MAE : [1.48508]
# Epoch : [33] Train Loss : [0.85516] Val MAE : [1.49617]
# Epoch : [34] Train Loss : [0.83170] Val MAE : [1.50051]
# Epoch : [35] Train Loss : [0.85668] Val MAE : [1.49763]
# Epoch : [36] Train Loss : [0.82020] Val MAE : [1.48158]
# Epoch 00036: reducing learning rate of group 0 to 7.8125e-05.
# Epoch : [37] Train Loss : [0.83936] Val MAE : [1.49203]
# Epoch : [38] Train Loss : [0.85962] Val MAE : [1.49715]
# Epoch : [39] Train Loss : [0.84615] Val MAE : [1.49739]
# Epoch : [40] Train Loss : [0.82448] Val MAE : [1.49887]
# Epoch : [41] Train Loss : [0.82618] Val MAE : [1.50099]
# Epoch 00041: reducing learning rate of group 0 to 3.9063e-05.
# Epoch : [42] Train Loss : [0.84138] Val MAE : [1.49179]
# Epoch : [43] Train Loss : [0.82749] Val MAE : [1.49504]
# Epoch : [44] Train Loss : [0.85053] Val MAE : [1.48742]
# Epoch : [45] Train Loss : [0.86253] Val MAE : [1.48374]
# Epoch : [46] Train Loss : [0.83931] Val MAE : [1.50028]
# Epoch 00046: reducing learning rate of group 0 to 1.9531e-05.
# Epoch : [47] Train Loss : [0.83108] Val MAE : [1.50130]
# Epoch : [48] Train Loss : [0.85966] Val MAE : [1.50149]
# Epoch : [49] Train Loss : [0.84818] Val MAE : [1.50062]
# Epoch : [50] Train Loss : [0.82882] Val MAE : [1.49981]
# Epoch : [51] Train Loss : [0.83157] Val MAE : [1.49699]
# Epoch 00051: reducing learning rate of group 0 to 9.7656e-06.
# Epoch : [52] Train Loss : [0.84769] Val MAE : [1.49697]
# Epoch : [53] Train Loss : [0.85952] Val MAE : [1.48667]
# Epoch : [54] Train Loss : [0.84210] Val MAE : [1.48612]
# Epoch : [55] Train Loss : [0.89207] Val MAE : [1.49673]
# Epoch : [56] Train Loss : [0.83983] Val MAE : [1.49496]
# Epoch 00056: reducing learning rate of group 0 to 4.8828e-06.
# Epoch : [57] Train Loss : [0.86719] Val MAE : [1.50253]
# Epoch : [58] Train Loss : [0.86508] Val MAE : [1.50191]
# Epoch : [59] Train Loss : [0.85184] Val MAE : [1.49960]
# Epoch : [60] Train Loss : [0.85744] Val MAE : [1.50191]
# Epoch : [61] Train Loss : [0.84615] Val MAE : [1.49053]
# Epoch 00061: reducing learning rate of group 0 to 2.4414e-06.
# Epoch : [62] Train Loss : [0.86916] Val MAE : [1.49238]
# Epoch : [63] Train Loss : [0.82989] Val MAE : [1.49515]
# Epoch : [64] Train Loss : [0.84050] Val MAE : [1.49134]
# Epoch : [65] Train Loss : [0.84267] Val MAE : [1.49296]
# Epoch : [66] Train Loss : [0.84271] Val MAE : [1.49852]
# Epoch 00066: reducing learning rate of group 0 to 1.2207e-06.
# Epoch : [67] Train Loss : [0.84751] Val MAE : [1.50208]
# Epoch : [68] Train Loss : [0.83145] Val MAE : [1.49319]
# Epoch : [69] Train Loss : [0.88412] Val MAE : [1.48945]
# Epoch : [70] Train Loss : [0.85115] Val MAE : [1.49507]
# Epoch : [71] Train Loss : [0.85034] Val MAE : [1.49597]
# Epoch 00071: reducing learning rate of group 0 to 6.1035e-07.
# Epoch : [72] Train Loss : [0.83429] Val MAE : [1.50359]
# Epoch : [73] Train Loss : [0.84154] Val MAE : [1.50175]
# Epoch : [74] Train Loss : [0.82148] Val MAE : [1.49841]
# Epoch : [75] Train Loss : [0.84173] Val MAE : [1.49344]
# Epoch : [76] Train Loss : [0.91131] Val MAE : [1.48847]
# Epoch 00076: reducing learning rate of group 0 to 3.0518e-07.
# Epoch : [77] Train Loss : [0.82581] Val MAE : [1.49440]
# Epoch : [78] Train Loss : [0.85497] Val MAE : [1.49852]
# Epoch : [79] Train Loss : [0.86639] Val MAE : [1.49180]
# Epoch : [80] Train Loss : [0.84682] Val MAE : [1.49347]
# Epoch : [81] Train Loss : [0.86170] Val MAE : [1.49507]
# Epoch 00081: reducing learning rate of group 0 to 1.5259e-07.
# Epoch : [82] Train Loss : [0.84375] Val MAE : [1.49401]
# Epoch : [83] Train Loss : [0.83313] Val MAE : [1.49328]
# Epoch : [84] Train Loss : [0.86995] Val MAE : [1.49069]
# Epoch : [85] Train Loss : [0.83521] Val MAE : [1.49482]
# Epoch : [86] Train Loss : [0.84763] Val MAE : [1.49762]
# Epoch 00086: reducing learning rate of group 0 to 7.6294e-08.
# Epoch : [87] Train Loss : [0.89197] Val MAE : [1.49674]
# Epoch : [88] Train Loss : [0.85831] Val MAE : [1.49673]
# Epoch : [89] Train Loss : [0.83335] Val MAE : [1.49258]
# Epoch : [90] Train Loss : [0.81681] Val MAE : [1.49289]
# Epoch : [91] Train Loss : [0.84511] Val MAE : [1.49240]
# Epoch 00091: reducing learning rate of group 0 to 3.8147e-08.
# Epoch : [92] Train Loss : [0.87852] Val MAE : [1.49031]
# Epoch : [93] Train Loss : [0.86761] Val MAE : [1.50203]
# Epoch : [94] Train Loss : [0.86057] Val MAE : [1.49238]
# Epoch : [95] Train Loss : [0.83278] Val MAE : [1.50052]
# Epoch : [96] Train Loss : [0.82718] Val MAE : [1.50130]
# Epoch 00096: reducing learning rate of group 0 to 1.9073e-08.
# Epoch : [97] Train Loss : [0.83989] Val MAE : [1.49192]
# Epoch : [98] Train Loss : [0.87116] Val MAE : [1.49142]
# Epoch : [99] Train Loss : [0.82573] Val MAE : [1.48875]
# Epoch : [100] Train Loss : [0.89282] Val MAE : [1.49051]
# Epoch : [101] Train Loss : [0.81686] Val MAE : [1.49260]
# Epoch : [102] Train Loss : [0.85984] Val MAE : [1.49841]
# Epoch : [103] Train Loss : [0.82359] Val MAE : [1.49332]
# Epoch : [104] Train Loss : [0.83675] Val MAE : [1.49522]
# Epoch : [105] Train Loss : [0.83917] Val MAE : [1.49199]
# Epoch : [106] Train Loss : [0.83585] Val MAE : [1.49394]
# Epoch : [107] Train Loss : [0.86051] Val MAE : [1.49525]
# Epoch : [108] Train Loss : [0.86549] Val MAE : [1.49792]
# Epoch : [109] Train Loss : [0.83486] Val MAE : [1.49999]
# Epoch : [110] Train Loss : [0.85931] Val MAE : [1.50555]
# Epoch : [111] Train Loss : [0.82654] Val MAE : [1.49538]
# Epoch : [112] Train Loss : [0.82386] Val MAE : [1.49496]
# Epoch : [113] Train Loss : [0.84569] Val MAE : [1.49267]
# Epoch : [114] Train Loss : [0.82260] Val MAE : [1.49409]
# Epoch : [115] Train Loss : [0.84589] Val MAE : [1.50095]
# Epoch : [116] Train Loss : [0.85229] Val MAE : [1.49271]
# Epoch : [117] Train Loss : [0.83702] Val MAE : [1.49432]
# Epoch : [118] Train Loss : [0.83792] Val MAE : [1.49367]
# Epoch : [119] Train Loss : [0.86133] Val MAE : [1.49978]
# Epoch : [120] Train Loss : [0.83348] Val MAE : [1.49411]
# Epoch : [121] Train Loss : [0.84124] Val MAE : [1.49648]
# Epoch : [122] Train Loss : [0.86403] Val MAE : [1.49398]
# Epoch : [123] Train Loss : [0.85788] Val MAE : [1.49410]
# Epoch : [124] Train Loss : [0.82607] Val MAE : [1.49641]
# Epoch : [125] Train Loss : [0.82081] Val MAE : [1.49388]
# Epoch : [126] Train Loss : [0.84640] Val MAE : [1.49367]
# Epoch : [127] Train Loss : [0.86839] Val MAE : [1.49152]
# Epoch : [128] Train Loss : [0.85087] Val MAE : [1.48576]
# Epoch : [129] Train Loss : [0.82719] Val MAE : [1.48938]
# Epoch : [130] Train Loss : [0.82737] Val MAE : [1.49343]
# Epoch : [131] Train Loss : [0.84993] Val MAE : [1.48817]
# Epoch : [132] Train Loss : [0.88988] Val MAE : [1.49076]
# Epoch : [133] Train Loss : [0.83172] Val MAE : [1.49179]
# Epoch : [134] Train Loss : [0.84405] Val MAE : [1.50178]
# Epoch : [135] Train Loss : [0.87299] Val MAE : [1.49750]
# Epoch : [136] Train Loss : [0.84339] Val MAE : [1.49102]
# Epoch : [137] Train Loss : [0.84124] Val MAE : [1.49105]
# Epoch : [138] Train Loss : [0.83685] Val MAE : [1.50094]
# Epoch : [139] Train Loss : [0.85002] Val MAE : [1.49886]
# Epoch : [140] Train Loss : [0.83950] Val MAE : [1.49702]
# Epoch : [141] Train Loss : [0.82178] Val MAE : [1.49815]
# Epoch : [142] Train Loss : [0.84132] Val MAE : [1.49164]
# Epoch : [143] Train Loss : [0.86008] Val MAE : [1.48916]
# Epoch : [144] Train Loss : [0.86551] Val MAE : [1.49165]
# Epoch : [145] Train Loss : [0.88136] Val MAE : [1.50069]
# Epoch : [146] Train Loss : [0.84297] Val MAE : [1.49495]
# Epoch : [147] Train Loss : [0.82564] Val MAE : [1.49163]
# Epoch : [148] Train Loss : [0.82103] Val MAE : [1.49440]
# Epoch : [149] Train Loss : [0.83699] Val MAE : [1.49342]
# Epoch : [150] Train Loss : [0.84134] Val MAE : [1.49751]
# Epoch : [151] Train Loss : [0.85011] Val MAE : [1.49841]
# Epoch : [152] Train Loss : [0.86557] Val MAE : [1.50571]
# Epoch : [153] Train Loss : [0.85082] Val MAE : [1.49638]
# Epoch : [154] Train Loss : [0.82929] Val MAE : [1.49299]
# Epoch : [155] Train Loss : [0.84240] Val MAE : [1.49139]
# Epoch : [156] Train Loss : [0.82953] Val MAE : [1.48815]
# Epoch : [157] Train Loss : [0.83141] Val MAE : [1.48874]
# Epoch : [158] Train Loss : [0.86194] Val MAE : [1.49181]
# Epoch : [159] Train Loss : [0.83729] Val MAE : [1.49590]
# Epoch : [160] Train Loss : [0.84875] Val MAE : [1.49421]
# Epoch : [161] Train Loss : [0.83572] Val MAE : [1.49781]
# Epoch : [162] Train Loss : [0.84423] Val MAE : [1.48729]
# Epoch : [163] Train Loss : [0.85403] Val MAE : [1.49150]
# Epoch : [164] Train Loss : [0.87909] Val MAE : [1.49433]
# Epoch : [165] Train Loss : [0.84143] Val MAE : [1.49273]
# Epoch : [166] Train Loss : [0.85647] Val MAE : [1.49620]
# Epoch : [167] Train Loss : [0.85044] Val MAE : [1.49139]
# Epoch : [168] Train Loss : [0.83255] Val MAE : [1.49659]
# Epoch : [169] Train Loss : [0.84827] Val MAE : [1.49580]
# Epoch : [170] Train Loss : [0.84449] Val MAE : [1.49965]
# Epoch : [171] Train Loss : [0.84061] Val MAE : [1.49539]
# Epoch : [172] Train Loss : [0.83216] Val MAE : [1.49516]
# Epoch : [173] Train Loss : [0.86397] Val MAE : [1.49437]
# Epoch : [174] Train Loss : [0.89319] Val MAE : [1.48981]
# Epoch : [175] Train Loss : [0.84737] Val MAE : [1.49409]
# Epoch : [176] Train Loss : [0.88641] Val MAE : [1.49468]
# Epoch : [177] Train Loss : [0.86329] Val MAE : [1.49774]
# Epoch : [178] Train Loss : [0.85012] Val MAE : [1.49548]
# Epoch : [179] Train Loss : [0.83709] Val MAE : [1.49305]
# Epoch : [180] Train Loss : [0.84777] Val MAE : [1.49374]
# Epoch : [181] Train Loss : [0.86917] Val MAE : [1.49087]
# Epoch : [182] Train Loss : [0.83856] Val MAE : [1.49369]
# Epoch : [183] Train Loss : [0.83724] Val MAE : [1.50419]
# Epoch : [184] Train Loss : [0.84588] Val MAE : [1.50122]
# Epoch : [185] Train Loss : [0.82046] Val MAE : [1.49647]
# Epoch : [186] Train Loss : [0.85874] Val MAE : [1.49499]
# Epoch : [187] Train Loss : [0.84513] Val MAE : [1.49776]
# Epoch : [188] Train Loss : [0.82382] Val MAE : [1.49881]
# Epoch : [189] Train Loss : [0.83813] Val MAE : [1.49319]
# Epoch : [190] Train Loss : [0.83440] Val MAE : [1.49662]
# Epoch : [191] Train Loss : [0.88308] Val MAE : [1.49699]
# Epoch : [192] Train Loss : [0.85052] Val MAE : [1.49240]
# Epoch : [193] Train Loss : [0.90597] Val MAE : [1.49926]
# Epoch : [194] Train Loss : [0.86449] Val MAE : [1.49408]
# Epoch : [195] Train Loss : [0.82685] Val MAE : [1.49565]
# Epoch : [196] Train Loss : [0.84910] Val MAE : [1.50201]
# Epoch : [197] Train Loss : [0.86905] Val MAE : [1.49293]
# Epoch : [198] Train Loss : [0.83025] Val MAE : [1.49206]
# Epoch : [199] Train Loss : [0.83751] Val MAE : [1.49370]
# Epoch : [200] Train Loss : [0.83430] Val MAE : [1.49233]

# %%
test = make_ymd_feature(submission)
test = pd.concat([val[CFG['X_RANGE']*(-1):], test]).reset_index().drop(columns='index')

# %%
test
# Out:
#          년         월         일    광진구   동대문구    성동구    중랑구
# 0    2.021  1.000000  0.870968  3.830  3.416  2.908  2.350
# 1    2.021  1.000000  0.903226  4.510  3.890  3.714  2.700
# 2    2.021  1.000000  0.935484  4.490  3.524  3.660  2.524
# 3    2.021  1.000000  0.967742  4.444  3.574  3.530  2.506
# 4    2.021  1.000000  1.000000  3.616  3.210  2.620  2.146
# ..     ...       ...       ...    ...    ...    ...    ...
# 334  2.022  0.916667  0.838710  0.000  0.000  0.000  0.000
# 335  2.022  0.916667  0.870968  0.000  0.000  0.000  0.000
# 336  2.022  0.916667  0.903226  0.000  0.000  0.000  0.000
# 337  2.022  0.916667  0.935484  0.000  0.000  0.000  0.000
# 338  2.022  0.916667  0.967742  0.000  0.000  0.000  0.000
#
# [339 rows x 7 columns]

# %%
def inference(model, df, device):
    model.to(device)
    model.eval()
    for i in tqdm(range(CFG['X_RANGE'], len(df))):
        X = torch.Tensor(np.array(df.loc[i-CFG['X_RANGE']:i-1, ['년', '월', '일', '광진구', '동대문구', '성동구', '중랑구']]).astype(float)).unsqueeze(0)
        X = X.to(device)
        with torch.no_grad():
            model_pred = model(X)[0]
        
        model_pred = model_pred.cpu().numpy()
        df.loc[i, ['광진구', '동대문구', '성동구', '중랑구']] = model_pred
    return df.loc[CFG['X_RANGE']:, ['광진구', '동대문구', '성동구', '중랑구']].reset_index().drop(columns=['index'])

# %%
preds = inference(best_model, test, device)
# Out:
#   0%|          | 0/334 [00:00<?, ?it/s]

# %%
submission['광진구'] = preds['광진구'].round(4)
submission['동대문구'] = preds['동대문구'].round(4)
submission['성동구'] = preds['성동구'].round(4)
submission['중랑구'] = preds['중랑구'].round(4)

# %%
submission
# Out:
#            일시     광진구    동대문구     성동구     중랑구
# 0    20220101  4.3270  2.5140  3.7023  1.7828
# 1    20220102  4.5405  2.6253  3.8845  1.8733
# 2    20220103  4.5242  2.6175  3.8717  1.8671
# 3    20220104  4.4706  2.5899  3.8265  1.8421
# 4    20220105  4.4987  2.6053  3.8528  1.8554
# ..        ...     ...     ...     ...     ...
# 329  20221126  3.6171  2.1508  3.0407  1.4860
# 330  20221127  3.6174  2.1510  3.0410  1.4861
# 331  20221128  3.6179  2.1513  3.0416  1.4863
# 332  20221129  3.6187  2.1518  3.0424  1.4866
# 333  20221130  3.6198  2.1524  3.0434  1.4869
#
# [334 rows x 5 columns]

# %% [markdown]
# ## Submission

# %%
save_path = base_path / 'submission'

# Check submission file name and define file name
if 'submission_bike.csv' in os.listdir(save_path):
    count = 0
    for name in os.listdir(save_path):
        if 'submission_bike' in name:
            count += 1
    filename = f"submission_bike{count + 1}.csv"
else:
    filename = 'submission_bike.csv'

# Export submission file
submission.to_csv(save_path / filename, index=False)
